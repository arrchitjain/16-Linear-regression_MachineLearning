# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("df_98039_N.csv")

# %%
df
# Out:
#     sqft_living      price
# 0          4860  2950000.0
# 1          4210  1910000.0
# 2          1220   875000.0
# 3          1220   940000.0
# 4          7080  4000000.0
# 5          9200  5570000.0
# 6          1320   937500.0
# 7          2680  1160000.0
# 8          2620  1880000.0
# 9          5450  3420000.0
# 10         2870  1560000.0
# 11         2640  1400000.0
# 12         2680  1320000.0
# 13         9890  6890000.0
# 14         1530   865000.0
# 15         2300  1000000.0
# 16         3550  2100000.0
# 17         4780  2580000.0
# 18         2660  1710000.0
# 19         1580   787500.0
# 20         3640  1650000.0
# 21         4460  1800000.0
# 22         2950  1550000.0
# 23         3060  1760000.0
# 24         2740  1230000.0
# 25         4430  2750000.0
# 26         4150  1950000.0
# 27         3570  2200000.0
# 28         3110  1260000.0
# 29         4670  2450000.0
# 30         4830  3640000.0
# 31         4040  2270000.0
# 32         2350  1620000.0
# ...

# %%
X = df["sqft_living"]
y = df["price"]

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
fig, ax = plt.subplots()
ax.plot(X, y, 'o', color='r', label = "training data")
ax.plot(X, 40000 + 400*X, label = 'h(x) = 400000 + 400 *X')

# %%
fig, ax = plt.subplots()
ax.plot(X, y, 'o', color='r', label='training data')
ax.plot(X, 10000 + 900*X, label='h(x) = 10000 + 900*x')
for i in range(len(X)):
    ax.plot([X[i], X[i]], [10000 + 900*X[i], y[i]], '-', color='c')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(X, y, 'o', color='r', label='training data')
ax.plot(X, 5000 + 600*X, label='h(x) = 5000 + 560*x')
for i in range(len(X)):
    ax.plot([X[i], X[i]], [5000 + 600*X[i],y[i]], '-', color='c')
plt.legend();

# %%
# simple function to demo 
def f(x) :                         #parabolla
    f = x ** 2
    return f
def Df(x):                         # derivative
    return 2*x
def update(x, alpha):              #update
    up = x - alpha * Df(x)
    return up

# %%
x = np.linspace(-5, 5, 100)
x
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
# ...

# %%
def plot_s(guess, alpha, epoch):
    fig, ax = plt.subplots()
    x = np.linspace(-5, 5, 100)
    ax.plot(x, f(x))
    x = guess
    ax.plot(x, f(x), 'o', label='start x=%.2f' %x)
    for i in range(epoch):
        xold = x
        x = update(x, alpha)
        ax.plot(x, f(x), 'o', label='x = %.2f' %x)
        ax.plot([xold, x], [f(xold), f(x)], '-')
    plt.legend()

# %% [markdown]
# Here is what happens if your step size is too small. It's slow to converge.

# %%
plot_s(-2, 0.5, 10)

# %%
plot_s(-2.5, 0.02, 10)

# %% [markdown]
# If the step size is too big it may overshoot the minimum and oscillate without getting to the minimum.

# %%
plot_s(-2.5, 0.9, 10)

# %% [markdown]
# If it's beyond a critical size it will "blow up" and start going up hill to infinity!

# %%
plot_s(-2.5, 1.05, 10)
